# %%
import pandas as pd

# %%
sals_ld = [(1, 1500.0), (2, 2000.0, 10.0), (3, 2200.00)]

# %%
s_df = pd.DataFrame(sals_ld)

# %%
s_df
# Out:
#    0       1     2
# 0  1  1500.0   NaN
# 1  2  2000.0  10.0
# 2  3  2200.0   NaN

# %%
s_df[0]
# Out:
# 0    1
# 1    2
# 2    3
# Name: 0, dtype: int64

# %%
s_df[0][0]
# Out:
# 1

# %%
s2_df = pd.DataFrame(sals_ld, columns = ['id', 'sal', 'com'])

# %%
s2_df
# Out:
#    id     sal   com
# 0   1  1500.0   NaN
# 1   2  2000.0  10.0
# 2   3  2200.0   NaN

# %%
s2_df['id']
# Out:
# 0    1
# 1    2
# 2    3
# Name: id, dtype: int64

# %%
s2_df[['id', 'sal']]
# Out:
#    id     sal
# 0   1  1500.0
# 1   2  2000.0
# 2   3  2200.0

# %%
sals_ld = [
    {'id': 1, 'sal': 1500.0},
    {'id': 2, 'sal': 2000.0},
    {'id': 3, 'sal': 2200.0}
]

# %%
s3_df = pd.DataFrame(sals_ld)

# %%
s3_df
# Out:
#    id     sal
# 0   1  1500.0
# 1   2  2000.0
# 2   3  2200.0
